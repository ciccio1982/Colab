# %% [markdown]
# <a href="https://colab.research.google.com/github/ciccio1982/Colab/blob/main/ricezione_messaggio_dalla_coda_solace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install solace-pubsubplus
# Out:
# Requirement already satisfied: solace-pubsubplus in /usr/local/lib/python3.12/dist-packages (1.11.0)

# %% [markdown]
# Before running the code, ensure you have the Solace PubSub+ Event Broker connection details ready. You'll need the host, message VPN name, and user credentials.
#
# You can create a free Solace Cloud account and get these details if you don't have a broker instance.

# %%
import os
import time

# Import Solace Python  API modules
from solace.messaging.messaging_service import MessagingService, ReconnectionListener, ReconnectionAttemptListener, ServiceInterruptionListener, RetryStrategy, ServiceEvent
from solace.messaging.errors.pubsubplus_client_error import PubSubPlusClientError
from solace.messaging.publisher.direct_message_publisher import PublishFailureListener, FailedPublishEvent
from solace.messaging.resources.topic_subscription import TopicSubscription
from solace.messaging.receiver.message_receiver import MessageHandler
from solace.messaging.config.solace_properties.message_properties import APPLICATION_MESSAGE_ID
from solace.messaging.resources.topic import Topic
from solace.messaging.resources.queue import Queue # Added Queue import
from solace.messaging.receiver.inbound_message import InboundMessage
# Solace Connection Details (replace with your actual values)
SOLACE_HOST = 'tcps://mr-connection-1d0n94c2091.messaging.solace.cloud:55443' # Changed to tcp:// for non-TLS
SOLACE_VPN = 'myfirstservice' # e.g., default
SOLACE_USERNAME = 'solace-cloud-client' # e.g., guest
SOLACE_PASSWORD = 'nj8nmnunpa68tg00rfa06hol8r' # e.g., guest

# Queue to send messages to
TARGET_QUEUE = 'test1'

# %%
broker_props = {
    "solace.messaging.transport.host": SOLACE_HOST,
    "solace.messaging.service.vpn-name": SOLACE_VPN,
    "solace.messaging.authentication.scheme.basic.username": SOLACE_USERNAME,
    "solace.messaging.authentication.scheme.basic.password": SOLACE_PASSWORD,
    # Disabilita validazione certificati
    "solace.messaging.tls.cert-validated": False,
    "solace.messaging.tls.cert-reject-expired": False
    # TLS-specific properties are removed for tcp:// connection
}
# Create the messaging service using from_properties
messaging_service = MessagingService.builder() \
  .from_properties(broker_props) \
  .with_reconnection_retry_strategy(RetryStrategy.parametrized_retry(20,3)) \
  .build()

# Blocking connect thread
messaging_service.connect()
print("CONNESSO!!!")
# Out:
# CONNESSO!!!

# %%
class MessageHandlerImpl(MessageHandler):
    def on_message(self, message: 'InboundMessage'):
        try:
            global SHUTDOWN
            if "quit" in message.get_destination_name():
                print("QUIT message received, shutting down.")
                SHUTDOWN = True

            # Check if the payload is a String or Byte, decode if its the later
            payload = message.get_payload_as_string() if message.get_payload_as_string() is not None else message.get_payload_as_bytes()
            if isinstance(payload, bytearray):
                print(f"Received a message of type: {type(payload)}. Decoding to string")
                payload = payload.decode()

            print("\n" + f"Message payload: {payload} \n")
            print("\n" + f"Message dump: {message} \n")
        except Exception as e:
            print(f"Error processing message: {e.__traceback__}")
# Inner classes for error handling
class ServiceEventHandler(ReconnectionListener, ReconnectionAttemptListener, ServiceInterruptionListener):
    def on_reconnected(self, e: ServiceEvent):
        print("\non_reconnected")
        print(f"Error cause: {e.get_cause()}")
        print(f"Message: {e.get_message()}")

    def on_reconnecting(self, e: "ServiceEvent"):
        print("\non_reconnecting")
        print(f"Error cause: {e.get_cause()}")
        print(f"Message: {e.get_message()}")

    def on_service_interrupted(self, e: "ServiceEvent"):
        print("\non_service_interrupted")
        print(f"Error cause: {e.get_cause()}")
        print(f"Message: {e.get_message()}")

class PublisherErrorHandling(PublishFailureListener):
    def on_failed_publish(self, e: "FailedPublishEvent"):
        print("on_failed_publish")

# %% [markdown]
# Next, we'll define a `MessageReceiver` class that implements the `MessageHandler` interface. This class will contain the logic to process incoming messages.

# %%
service_handler = ServiceEventHandler()
messaging_service.add_reconnection_listener(service_handler)
messaging_service.add_reconnection_attempt_listener(service_handler)
messaging_service.add_service_interruption_listener(service_handler)

# Create a queue destination
#queue = Queue.durable_queue(TARGET_QUEUE) # Changed from Topic.of to Queue.durable_queue
queue = Queue.durable_non_exclusive_queue(TARGET_QUEUE)  # o
# Build a Persistent Message Consumer with the given queue and start it
persistent_consumer = messaging_service.create_persistent_message_receiver_builder()\
                         .build(queue)


persistent_consumer.start()
print(f'Persistent Consumer is running? {persistent_consumer.is_running()}')

try:
    print(f"Subscribing to queue: {TARGET_QUEUE}")
    # Callback for received messages
    persistent_consumer.receive_async(MessageHandlerImpl())
    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        print('\nDisconnecting Messaging Service')
finally:
    print('\nTerminating consumer')
    persistent_consumer.terminate()
    print('\nDisconnecting Messaging Service')
    messaging_service.disconnect()
# Out:
# Persistent Consumer is running? True
# Subscribing to queue: test1
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             1
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) ed0d06185b8312f4
#   Key 'otel_parent_trace_id' (STRING) 20128964f0d23b5ab3fb7e3c9aab1a32
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-0000001a
# Tracing CreationContext:                 {traceId=20128964f0d23b5ab3fb7e3c9aab1a32, spanId=ed0d06185b8312f4, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             2
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) da538216201bc1b7
#   Key 'otel_parent_trace_id' (STRING) 0ecdcdc45e26021ea20c7d9a07a4c90c
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-0000001b
# Tracing CreationContext:                 {traceId=0ecdcdc45e26021ea20c7d9a07a4c90c, spanId=da538216201bc1b7, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             3
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) ccc02287819ed2f0
#   Key 'otel_parent_trace_id' (STRING) b1436a4e4ee863d38795fbe9b4677f36
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-0000001c
# Tracing CreationContext:                 {traceId=b1436a4e4ee863d38795fbe9b4677f36, spanId=ccc02287819ed2f0, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             4
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) e9e4e75b5c3ea0e9
#   Key 'otel_parent_trace_id' (STRING) 92afc5e2d28df04b0262cce089ebb384
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-0000001d
# Tracing CreationContext:                 {traceId=92afc5e2d28df04b0262cce089ebb384, spanId=e9e4e75b5c3ea0e9, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             5
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) 76bc84915b91f5ac
#   Key 'otel_parent_trace_id' (STRING) 836b81f63e4eafdf4cc35ba3ad0f3aae
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-0000001e
# Tracing CreationContext:                 {traceId=836b81f63e4eafdf4cc35ba3ad0f3aae, spanId=76bc84915b91f5ac, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             6
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) bdb7bdcf0949ee2a
#   Key 'otel_parent_trace_id' (STRING) 8136b26f70aa31c721b917677c2b6dec
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-0000001f
# Tracing CreationContext:                 {traceId=8136b26f70aa31c721b917677c2b6dec, spanId=bdb7bdcf0949ee2a, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             7
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) 1637ae01e52d7340
#   Key 'otel_parent_trace_id' (STRING) 981ce5a3d79e66e7d2abd21dfbb9de19
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-00000020
# Tracing CreationContext:                 {traceId=981ce5a3d79e66e7d2abd21dfbb9de19, spanId=1637ae01e52d7340, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             8
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) ddd5bef8cbea6ef0
#   Key 'otel_parent_trace_id' (STRING) c71fbe3392137cd78b16c331c6901d7a
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-00000021
# Tracing CreationContext:                 {traceId=c71fbe3392137cd78b16c331c6901d7a, spanId=ddd5bef8cbea6ef0, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             9
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) c55ec495df2a65f9
#   Key 'otel_parent_trace_id' (STRING) e174483e2c9cb285acd4c440169c4fe6
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-00000022
# Tracing CreationContext:                 {traceId=e174483e2c9cb285acd4c440169c4fe6, spanId=c55ec495df2a65f9, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: qualcosa
#
#
# Message dump: Destination:                            Topic 'topic'
# Priority:                               4
# HTTP Content Type:                      application/java
# HTTP Content Encoding:                  UTF-8
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             10
# DMQ Eligible
# Message Re-delivered
# User Property Map:
#   Key 'otel_parent_span_id' (STRING) 1039c5f9e9343c00
#   Key 'otel_parent_trace_id' (STRING) 133d9f5156f6eef0a08d48a9e9b2d680
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-00000023
# Tracing CreationContext:                 {traceId=133d9f5156f6eef0a08d48a9e9b2d680, spanId=1039c5f9e9343c00, sampled=false, traceState=}
# Binary Attachment String:               len=8
#   71 75 61 6c 63 6f 73 61                               qualcosa
#
#
#
# Message payload: Hello from Google Colab! This is a test message.
#
#
# Message dump: Destination:                            Topic 'topic'
# ApplicationMessageId:                   my-message-id-1
# Priority:                               4
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             11
# DMQ Eligible
# Message Re-delivered
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-00000024
# Binary Attachment String:               len=48
#   48 65 6c 6c 6f 20 66 72  6f 6d 20 47 6f 6f 67 6c      Hello fr   om Googl
#   65 20 43 6f 6c 61 62 21  20 54 68 69 73 20 69 73      e Colab!    This is
#   20 61 20 74 65 73 74 20  6d 65 73 73 61 67 65 2e       a test    message.
#
#
#
# Message payload: Hello from Google Colab! This is a test message.
#
#
# Message dump: Destination:                            Topic 'topic'
# ApplicationMessageId:                   my-message-id-1
# Priority:                               4
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             12
# DMQ Eligible
# Message Re-delivered
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-00000025
# Binary Attachment String:               len=48
#   48 65 6c 6c 6f 20 66 72  6f 6d 20 47 6f 6f 67 6c      Hello fr   om Googl
#   65 20 43 6f 6c 61 62 21  20 54 68 69 73 20 69 73      e Colab!    This is
#   20 61 20 74 65 73 74 20  6d 65 73 73 61 67 65 2e       a test    message.
#
#
#
# Message payload: Hello from Google Colab! This is a test message.
#
#
# Message dump: Destination:                            Topic 'topic'
# ApplicationMessageId:                   my-message-id-1
# Priority:                               4
# Class Of Service:                       COS_1
# DeliveryMode:                           NON-PERSISTENT
# Message Id:                             13
# DMQ Eligible
# Replication Group Message Id:           rmid1:4b26f-dd6ee20c044-00000000-00000026
# Binary Attachment String:               len=48
#   48 65 6c 6c 6f 20 66 72  6f 6d 20 47 6f 6f 67 6c      Hello fr   om Googl
#   65 20 43 6f 6c 61 62 21  20 54 68 69 73 20 69 73      e Colab!    This is
#   20 61 20 74 65 73 74 20  6d 65 73 73 61 67 65 2e       a test    message.
#
#
#
# Disconnecting Messaging Service
#
# Terminating consumer
#
# Disconnecting Messaging Service

# %% [markdown]
# Finally, we'll initialize the Solace messaging service, create a consumer, bind it to the specified queue, and start listening for messages. The consumer will run in a separate thread, and the main thread will wait for a stop signal.
